# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 加载图像（假设你已经下载了那张OCTA图像并与notebook文件在同一目录）
image = cv2.imread("octa_image.png", cv2.IMREAD_GRAYSCALE)

# 图像增强（对比度增强）
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
enhanced = clahe.apply(image)

# 边缘检测（Canny）
edges = cv2.Canny(enhanced, 50, 150)

# 显示处理过程
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(image, cmap='gray')
ax[0].set_title("Original")
ax[0].axis("off")

ax[1].imshow(enhanced, cmap='gray')
ax[1].set_title("Enhanced")
ax[1].axis("off")

ax[2].imshow(edges, cmap='gray')
ax[2].set_title("Edges")
ax[2].axis("off")

plt.tight_layout()
plt.show()

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\xbei\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\xbei\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
